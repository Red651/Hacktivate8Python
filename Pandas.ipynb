# %%
import pandas as pd

# %%
df = pd.read_csv('Dataset/nbaallelo.csv')

# %%
# Memunculkan data dari 5 ter-atas
df.head()
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id  date_game  seasongame  \
# 0          1  194611010TRH   NBA        0     1947  11/1/1946           1
# 1          1  194611010TRH   NBA        1     1947  11/1/1946           1
# 2          2  194611020CHS   NBA        0     1947  11/2/1946           1
# 3          2  194611020CHS   NBA        1     1947  11/2/1946           2
# 4          3  194611020DTF   NBA        0     1947  11/2/1946           1
#
#    is_playoffs team_id  fran_id  ...  win_equiv  opp_id  opp_fran  opp_pts  \
# 0            0     TRH  Huskies  ...  40.294830     NYK    Knicks       68
# 1            0     NYK   Knicks  ...  41.705170     TRH   Huskies       66
# 2            0     CHS    Stags  ...  42.012257     NYK    Knicks       47
# 3            0     NYK   Knicks  ...  40.692783     CHS     Stags       63
# 4            0     DTF  Falcons  ...  38.864048     WSC  Capitols       50
#
#    opp_elo_i  opp_elo_n  game_location  game_result  forecast notes
# ...

# %%
# Mengambil data dari 5 ter bawah
df.tail()
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 126309         100            1     CLE  Cavaliers  ...  60.309792     GSW
# 126310         102            1     GSW   Warriors  ...  68.013329     CLE
# 126311         101            1     CLE  Cavaliers  ...  60.010067     GSW
# 126312         102            1     CLE  Cavaliers  ...  59.290245     GSW
# 126313         103            1     GSW   Warriors  ...  68.519516     CLE
#
#          opp_fran  opp_pts  opp_elo_i  opp_elo_n  game_location  game_result  \
# ...

# %%
# untuk memberikan informasi mengenai data yang kita pilih
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126314 entries, 0 to 126313
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameorder      126314 non-null  int64
#  1   game_id        126314 non-null  object
#  2   lg_id          126314 non-null  object
#  3   _iscopy        126314 non-null  int64
#  4   year_id        126314 non-null  int64
#  5   date_game      126314 non-null  object
#  6   seasongame     126314 non-null  int64
#  7   is_playoffs    126314 non-null  int64
#  8   team_id        126314 non-null  object
#  9   fran_id        126314 non-null  object
#  10  pts            126314 non-null  int64
#  11  elo_i          126314 non-null  float64
#  12  elo_n          126314 non-null  float64
#  13  win_equiv      126314 non-null  float64
#  14  opp_id         126314 non-null  object
#  15  opp_fran       126314 non-null  object
#  16  opp_pts        126314 non-null  int64
# ...

# %%
# untuk mengetahui statistik dari data yang kita pilih
df.describe()
# Out:
#            gameorder        _iscopy        year_id     seasongame  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean    31579.000000       0.500000    1988.200374      43.533733
# std     18231.927643       0.500002      17.582309      25.375178
# min         1.000000       0.000000    1947.000000       1.000000
# 25%     15790.000000       0.000000    1975.000000      22.000000
# 50%     31579.000000       0.500000    1990.000000      43.000000
# 75%     47368.000000       1.000000    2003.000000      65.000000
# max     63157.000000       1.000000    2015.000000     108.000000
#
#          is_playoffs            pts          elo_i          elo_n  \
# count  126314.000000  126314.000000  126314.000000  126314.000000
# mean        0.063857     102.729982    1495.236055    1495.236055
# std         0.244499      14.814845     112.139945     112.461687
# min         0.000000       0.000000    1091.644500    1085.774400
# ...

# %%
df['team_id'].value_counts()
# Out:
# BOS    5997
# NYK    5769
# LAL    5078
# DET    4985
# PHI    4533
#        ...
# TRH      60
# PIT      60
# INJ      60
# DTF      60
# SDS      11
# Name: team_id, Length: 104, dtype: int64

# %%
df.loc[df['team_id'] == 'LAL', 'date_game'].min()
# Out:
# '1/1/1961'

# %%
df.loc[df['team_id'] == 'LAL', 'date_game'].max()
# Out:
# '6/9/2009'

# %%
df.loc[df['team_id'] == 'LAL', 'pts'].sum()
# Out:
# 549215

# %%
revenues = pd.Series([5555, 7000, 1980])

# %%
revenues
# Out:
# 0    5555
# 1    7000
# 2    1980
# dtype: int64

# %%
revenues.index # untuk mengetahui index dari data yang kita pilih
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
revenues.values # untuk mengetahui nilai dari data yang kita pilih
# Out:
# array([5555, 7000, 1980], dtype=int64)

# %%
city_revenues = pd.Series([4200, 8000, 6500], 
                index=['Amsterdam', 'Toronto', 'Tokyo'])
city_revenues
# Out:
# Amsterdam    4200
# Toronto      8000
# Tokyo        6500
# dtype: int64

# %%
city_employee_count = pd.Series({'Amsterdam': 5, 'Tokyo': 8})
city_employee_count
# Out:
# Amsterdam    5
# Tokyo        8
# dtype: int64

# %%
city_employee_count.keys()
# Out:
# Index(['Amsterdam', 'Tokyo'], dtype='object')

# %%
'Tokyo' in city_employee_count
# Out:
# True

# %%
'New York' in city_employee_count
# Out:
# False

# %% [markdown]
# ## understanding Data Frame Object

# %%
city_data = pd.DataFrame({'revenue': city_revenues,
                        'employee_count': city_employee_count})
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
city_data.index
# Out:
# Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object')

# %%
city_data.values
# Out:
# array([[4.2e+03, 5.0e+00],
#        [6.5e+03, 8.0e+00],
#        [8.0e+03,     nan]])

# %%
city_data.axes
# Out:
# [Index(['Amsterdam', 'Tokyo', 'Toronto'], dtype='object'),
#  Index(['revenue', 'employee_count'], dtype='object')]

# %%
df[df['year_id'] == 2015]
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id   date_game  \
# 123692      61847  201410280LAL   NBA        1     2015  10/28/2014
# 123693      61847  201410280LAL   NBA        0     2015  10/28/2014
# 123694      61848  201410280NOP   NBA        0     2015  10/28/2014
# 123695      61848  201410280NOP   NBA        1     2015  10/28/2014
# 123696      61849  201410280SAS   NBA        0     2015  10/28/2014
# ...           ...           ...   ...      ...      ...         ...
# 126309      63155  201506110CLE   NBA        0     2015   6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015   6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015   6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015   6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015   6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# ...

# %%
df.shape
# Out:
# (126314, 23)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=126314, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=126314, step=1),
#  Index(['gameorder', 'game_id', 'lg_id', '_iscopy', 'year_id', 'date_game',
#         'seasongame', 'is_playoffs', 'team_id', 'fran_id', 'pts', 'elo_i',
#         'elo_n', 'win_equiv', 'opp_id', 'opp_fran', 'opp_pts', 'opp_elo_i',
#         'opp_elo_n', 'game_location', 'game_result', 'forecast', 'notes'],
#        dtype='object')]

# %%
"points" in df.keys()
# Out:
# False

# %%
"pts" in df.keys()
# Out:
# True

# %% [markdown]
# ## Acessing Series Elements

# %%
# menggunakan iloc untuk mengambil data dari baris dan kolom
df.iloc[0:5, 0:5]
# Out:
#    gameorder       game_id lg_id  _iscopy  year_id
# 0          1  194611010TRH   NBA        0     1947
# 1          1  194611010TRH   NBA        1     1947
# 2          2  194611020CHS   NBA        0     1947
# 3          2  194611020CHS   NBA        1     1947
# 4          3  194611020DTF   NBA        0     1947

# %%
# mnggunakan loc untuk mengambil data dari baris dan kolom
df.loc[0:5, 'gameorder':'lg_id']
# Out:
#    gameorder       game_id lg_id
# 0          1  194611010TRH   NBA
# 1          1  194611010TRH   NBA
# 2          2  194611020CHS   NBA
# 3          2  194611020CHS   NBA
# 4          3  194611020DTF   NBA
# 5          3  194611020DTF   NBA

# %%
# perbedaan antara iloc dan loc adalah iloc menggunakan index sedangkan loc menggunakan nama kolom

# %%
# groupby untuk mengelompokkan data
df.groupby('fran_id', sort=False)['pts'].sum()
# Out:
# fran_id
# Huskies           3995
# Knicks          582497
# Stags            20398
# Falcons           3797
# Capitols         22387
# Celtics         626484
# Steamrollers     12372
# Ironmen           3674
# Bombers          17793
# Rebels            4474
# Warriors        591224
# Baltimore        37219
# Jets              4482
# Pistons         572758
# Lakers          637444
# Kings           569245
# Hawks           567261
# Denver            4818
# Olympians        22864
# Redskins          5372
# Waterloo          4921
# Packers           6193
# Sixers          585891
# Wizards         474809
# Bulls           437269
# Thunder         437735
# Squires          91127
# Stars            84940
# Rockets         432504
# Colonels         94435
# Pacers          438288
# Nuggets         445780
# Spurs           453822
# Spirits          85874
# Sounds           75582
# Floridians       49568
# Nets            417809
# Condors          49642
# Bucks           418326
# ...

# %%
# untuk mengambil data dari kolom yang kita pilih dan mengelompokkannya 
df[
    (df['fran_id'] == 'Knicks') &
    (df['year_id'] > 2010)
].groupby(['year_id', 'game_result'])['game_id'].count()
# Out:
# year_id  game_result
# 2011     L              44
#          W              42
# 2012     L              34
#          W              37
# 2013     L              34
#          W              60
# 2014     L              45
#          W              37
# 2015     L              65
#          W              17
# Name: game_id, dtype: int64

# %% [markdown]
# ## Combining dataset
#
# <img src='https://lh3.googleusercontent.com/zRbhkKOXHOigOENTNEzTvxixLyJMCyI3bkTFjpBdFnBXNqk8kgmMfGyebldznaAxgBya6STeOIxLJ11CFWDnQArAGuL_JFGcq_E_vG2DBiGDpo1TABGsgoVhDNyzaIK_ZqFhM5NB8h7y7xwXJA' style='text-align:center'>

# %%
further_city_data = pd.DataFrame({'revenue': [7000, 3400],
                                'employee_count': [2, 2]},
                                index=['New York', 'Barcelona'])
further_city_data
# Out:
#            revenue  employee_count
# New York      7000               2
# Barcelona     3400               2

# %%
city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN

# %%
all_city_data = pd.concat([city_data, further_city_data]) # untuk menggabungkan data

# %%
all_city_data
# Out:
#            revenue  employee_count
# Amsterdam     4200             5.0
# Tokyo         6500             8.0
# Toronto       8000             NaN
# New York      7000             2.0
# Barcelona     3400             2.0

# %%
city_coutry = pd.DataFrame({'country': ['Holland', 'Holland', 'Japan', 'USA', 'USA'],
                            'capital': [1, 0, 0, 1, 0]},
                            index=['Amsterdam', 'Rotterdam', 'Tokyo', 'New York', 'Barcelona'])

# %%
city_coutry
# Out:
#            country  capital
# Amsterdam  Holland        1
# Rotterdam  Holland        0
# Tokyo        Japan        0
# New York       USA        1
# Barcelona      USA        0

# %%
cities = pd.concat([all_city_data, city_coutry], axis=1, sort=False) # untuk menggabungkan data
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      0.0
# Toronto     8000.0             NaN      NaN      NaN
# New York    7000.0             2.0      USA      1.0
# Barcelona   3400.0             2.0      USA      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.concat([all_city_data, city_coutry], axis=1, sort=False, join='inner')
# inner untuk menggabungkan data yang sama saja
# Out:
#            revenue  employee_count  country  capital
# Amsterdam     4200             5.0  Holland        1
# Tokyo         6500             8.0    Japan        0
# New York      7000             2.0      USA        1
# Barcelona     3400             2.0      USA        0

# %%
countries = pd.DataFrame({'population_millions': [17, 127, 37],
                        'continent': ['Europe', 'North America', 'Asia']},
                        index=['Holland', 'USA', 'Japan'])

# %%
countries
# Out:
#          population_millions      continent
# Holland                   17         Europe
# USA                      127  North America
# Japan                     37           Asia

# %%
cities
# Out:
#            revenue  employee_count  country  capital
# Amsterdam   4200.0             5.0  Holland      1.0
# Tokyo       6500.0             8.0    Japan      0.0
# Toronto     8000.0             NaN      NaN      NaN
# New York    7000.0             2.0      USA      1.0
# Barcelona   3400.0             2.0      USA      0.0
# Rotterdam      NaN             NaN  Holland      0.0

# %%
pd.merge(cities, countries, left_on='country', right_index=True) # untuk menggabungkan data
# Out:
#            revenue  employee_count  country  capital  population_millions  \
# Amsterdam   4200.0             5.0  Holland      1.0                   17
# Rotterdam      NaN             NaN  Holland      0.0                   17
# Tokyo       6500.0             8.0    Japan      0.0                   37
# New York    7000.0             2.0      USA      1.0                  127
# Barcelona   3400.0             2.0      USA      0.0                  127
#
#                continent
# Amsterdam         Europe
# Rotterdam         Europe
# Tokyo               Asia
# New York   North America
# Barcelona  North America

# %% [markdown]
# ## visualisasi pandas

# %%
# visualisasi data menggunakan .plot()

# %%
# fungsi %matplotlib inline untuk menampilkan plot di notebook
# %matplotlib inline

# %%
df
# Out:
#         gameorder       game_id lg_id  _iscopy  year_id  date_game  \
# 0               1  194611010TRH   NBA        0     1947  11/1/1946
# 1               1  194611010TRH   NBA        1     1947  11/1/1946
# 2               2  194611020CHS   NBA        0     1947  11/2/1946
# 3               2  194611020CHS   NBA        1     1947  11/2/1946
# 4               3  194611020DTF   NBA        0     1947  11/2/1946
# ...           ...           ...   ...      ...      ...        ...
# 126309      63155  201506110CLE   NBA        0     2015  6/11/2015
# 126310      63156  201506140GSW   NBA        0     2015  6/14/2015
# 126311      63156  201506140GSW   NBA        1     2015  6/14/2015
# 126312      63157  201506170CLE   NBA        0     2015  6/16/2015
# 126313      63157  201506170CLE   NBA        1     2015  6/16/2015
#
#         seasongame  is_playoffs team_id    fran_id  ...  win_equiv  opp_id  \
# 0                1            0     TRH    Huskies  ...  40.294830     NYK
# ...

# %%
df[df['fran_id'] == 'Lakers'].groupby('year_id')['pts'].sum().plot()
# Out:
# <Axes: xlabel='year_id'>

# %%
df[df['fran_id'] == 'Lakers'].groupby('year_id')['opp_pts'].sum()
# Out:
# year_id
# 1949    5328
# 1950    6131
# 1951    5839
# 1952    6276
# 1953    6476
#         ...
# 2011    8765
# 2012    7506
# 2013    8702
# 2014    8958
# 2015    8634
# Name: opp_pts, Length: 67, dtype: int64

# %%
df["fran_id"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
df["fran_id"].value_counts().head(10)
# Out:
# Lakers      6024
# Celtics     5997
# Knicks      5769
# Warriors    5657
# Pistons     5650
# Sixers      5644
# Hawks       5572
# Kings       5475
# Wizards     4582
# Spurs       4309
# Name: fran_id, dtype: int64
